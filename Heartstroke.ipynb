# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (8,5)
sns.set_style("whitegrid")

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\Kaggle\Cat and dog\healthcare-dataset-stroke-data.csv")

df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print("Shape of Dataset:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)

print("\nDataset Information:")
df.info()
# Out:
# Shape of Dataset:
# (5110, 12)
#
# Columns:
# ['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status', 'stroke']
#
# Data Types:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
# ...

# %%
df.describe(include='all')
# Out:
#                   id  gender          age  hypertension  heart_disease  \
# count    5110.000000    5110  5110.000000   5110.000000    5110.000000
# unique           NaN       3          NaN           NaN            NaN
# top              NaN  Female          NaN           NaN            NaN
# freq             NaN    2994          NaN           NaN            NaN
# mean    36517.829354     NaN    43.226614      0.097456       0.054012
# std     21161.721625     NaN    22.612647      0.296607       0.226063
# min        67.000000     NaN     0.080000      0.000000       0.000000
# 25%     17741.250000     NaN    25.000000      0.000000       0.000000
# 50%     36932.000000     NaN    45.000000      0.000000       0.000000
# 75%     54682.000000     NaN    61.000000      0.000000       0.000000
# max     72940.000000     NaN    82.000000      1.000000       1.000000
#
#        ever_married work_type Residence_type  avg_glucose_level          bmi  \
# ...

# %%
missing_values = df.isnull().sum()

print(missing_values)

missing_percentage = (df.isnull().sum()/len(df))*100

pd.DataFrame({
    "Missing Values": missing_values,
    "Percentage": missing_percentage
})
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64
#                    Missing Values  Percentage
# id                              0    0.000000
# gender                          0    0.000000
# age                             0    0.000000
# hypertension                    0    0.000000
# heart_disease                   0    0.000000
# ever_married                    0    0.000000
# work_type                       0    0.000000
# Residence_type                  0    0.000000
# avg_glucose_level               0    0.000000
# bmi                           201    3.933464
# smoking_status                  0    0.000000
# stroke                          0    0.000000

# %%
duplicates = df.duplicated().sum()

print("Duplicate Records:", duplicates)
# Out:
# Duplicate Records: 0

# %%
numerical_features = df.select_dtypes(include=np.number).columns.tolist()

categorical_features = df.select_dtypes(include='object').columns.tolist()

print("Numerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
# ['id', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']
#
# Categorical Features:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
plt.hist(df['age'], bins=30)
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['avg_glucose_level'], bins=30)
plt.title("Distribution of Average Glucose Level")
plt.xlabel("Glucose Level")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='stroke', data=df)
plt.title("Stroke Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='stroke', y='age', data=df)
plt.title("Age Distribution by Stroke Status")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='age', y='avg_glucose_level', hue='stroke', data=df)
plt.title("Age vs Average Glucose Level")
plt.show()

# %%
corr = df.select_dtypes(include=np.number).corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='work_type', hue='stroke', data=df)
plt.title("Stroke Cases by Work Type")
plt.show()

# %% [markdown]
# 1. The dataset contains 5110 records and 12 features.
# 2. BMI is the only feature with missing values.
# 3. No duplicate records are present.
# 4. The target variable (stroke) is highly imbalanced.
# 5. Age is strongly associated with stroke occurrence.
# 6. Stroke cases are more common among older individuals.
# 7. Average glucose level shows a positive relationship with stroke.
# 8. The glucose level distribution is right-skewed.
# 9. Gender distribution is relatively balanced between males and females.
# 10. Most individuals belong to the private work category.
# 11. Higher age and glucose levels appear to increase stroke risk.
# 12. Feature engineering and class balancing techniques may improve predictive modeling.
